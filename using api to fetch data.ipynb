# %%
import pandas as pd
import requests

# %%
url='https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc'
header={
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3MDA2YmU3ZjU2NGY0NzIzZTAwYTdiNmI1MTM4YzIxYSIsIm5iZiI6MS43NDYyODM3NjcxNTM5OTk4ZSs5LCJzdWIiOiI2ODE2MmNmN2M1NTljNDJkNWYzYzZlYzEiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.EVQdjjcDHsCogQI-mPZInjq3T7HSNZxTKGeDpgQleTM",
    'accept': 'application/json'
}
response=requests.get(url,headers=header)
r=response.json()
pandas.json_normalize(r,'results')
# pd.DataFrame(response.json()['results'])[['id','title','popularity','vote_average','vote_count']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 8
#       6 response=requests.get(url,headers=header)
#       7 r=response.json()
# ----> 8 pandas.json_normalize(r,'results')
#
# NameError: name 'pandas' is not defined

# %%
import requests

url = "https://spotify23.p.rapidapi.com/track_lyrics/"

querystring = {"id":"4snRyiaLyvTMui0hzp8MF7"}

headers = {
	"x-rapidapi-key": "e6617a5624msh5a544b9acf5fca0p19785ajsn168ec36b077e",
	"x-rapidapi-host": "spotify23.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

pd.DataFrame(response.json())
# Out:
#                                                                 lyrics  \
# syncType                                                   LINE_SYNCED
# lines                [{'startTimeMs': '50', 'words': 'Run like this...
# provider                                                    MusixMatch
# providerLyricsId                                             198920318
# providerDisplayName                                         Musixmatch
# syncLyricsUri
# isDenseTypeface                                                  False
# alternatives                                                        []
# language                                                            en
# isRtlLanguage                                                    False
# capStatus                                                     UNCAPPED
# previewLines         [{'startTimeMs': '50', 'words': 'Run like this...
# background                                                         NaN
# ...

# %%
import requests

url = "https://ev-charge-finder.p.rapidapi.com/search-by-location"

querystring = {"near":"New York, NY, USA","limit":"20"}

headers = {
	"x-rapidapi-key": "e6617a5624msh5a544b9acf5fca0p19785ajsn168ec36b077e",
	"x-rapidapi-host": "ev-charge-finder.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

pd.DataFrame(response.json())
# Out:
#    status                            request_id  \
# 0      OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 1      OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 2      OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 3      OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 4      OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 5      OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 6      OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 7      OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 8      OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 9      OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 10     OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 11     OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 12     OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 13     OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 14     OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 15     OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 16     OK  6f021e72-ca9d-4185-a241-a30b6df45583
# 17     OK  6f021e72-ca9d-4185-a241-a30b6df45583
# ...

# %%
import pandas as pd
import requests

# Set up the URL and parameters for the API request
url = "https://ev-charge-finder.p.rapidapi.com/search-by-location"
querystring = {"near": "New York, NY, USA", "limit": "20"}

# Set up the headers
headers = {
    "x-rapidapi-key": "e6617a5624msh5a544b9acf5fca0p19785ajsn168ec36b077e",
    "x-rapidapi-host": "ev-charge-finder.p.rapidapi.com"
}

# Send the GET request to the API
response = requests.get(url, headers=headers, params=querystring)

# Parse the JSON response
response_json = response.json()

# Check if the response contains data
if 'data' in response_json:
    # Extract the list of charging stations from the response
    stations = response_json['data']
    
    # Flatten the nested JSON structure into a tabular format
    df = pd.json_normalize(stations)
    
    # Optional: Rename columns for readability (optional step)
    df.rename(columns={
        'location.address': 'Address',
        'location.city': 'City',
        'location.state': 'State',
        'location.zip': 'ZipCode',
        'location.country': 'Country',
        'location.latitude': 'Latitude',
        'location.longitude': 'Longitude',
        'station_name': 'Station Name',
        'station_id': 'Station ID',
        'charging_compatible': 'Compatible Charging',
        'connectors': 'Connectors'
    }, inplace=True)
    
    # Display the first few rows of the DataFrame
    p
else:
    print("No data found in the response.")
# Out:
#                                       id                          name  \
# 0  0x89c25b3949822bfd:0xb095830dd40f7925        Revel Charging Station
# 1  0x89c2fa0ef253d2b9:0xbb109d0d15bbd5d0  ChargePoint Charging Station
# 2  0x89c25a2787498e69:0xc5d34e34fc306102            Tesla Supercharger
# 3  0x89c25b60a254bfcd:0x1915940026b9f67e            Tesla Supercharger
# 4  0x89c25987820fcb65:0xbebc8fb8d051614f            Tesla Supercharger
#
#                                           Connectors  \
# 0  [{'type': 'CCS', 'total': 5, 'available': None...
# 1  [{'type': 'CHAdeMO', 'total': 2, 'available': ...
# 2  [{'type': 'Tesla', 'total': 2, 'available': No...
# 3  [{'type': 'Tesla', 'total': 4, 'available': No...
# 4  [{'type': 'Tesla', 'total': 4, 'available': No...
#
#                           formatted_address   latitude  longitude  \
# 0  299 South St Pier 36, New York, NY 10002  40.710225 -73.986061
# 1        520 River St, Hackensack, NJ 07601  40.894743 -74.038254
# ...

# %%
import requests

url = "https://meteostat.p.rapidapi.com/point/monthly"

querystring = {"lat":"52.5244","lon":"13.4105","alt":"43","start":"2020-01-01","end":"2020-12-31"}

headers = {
	"x-rapidapi-key": "e6617a5624msh5a544b9acf5fca0p19785ajsn168ec36b077e",
	"x-rapidapi-host": "meteostat.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
response.json()
# Out:
# {'meta': {'generated': '2025-04-28 12:44:26',
#   'stations': ['10384', '10382', '10381', 'D0420']},
#  'data': [{'date': '2020-01-01 00:00:00',
#    'tavg': 4.7,
#    'tmin': 1.8,
#    'tmax': 7.3,
#    'prcp': 34.0,
#    'wspd': 13.2,
#    'pres': 1021.4,
#    'tsun': 3660},
#   {'date': '2020-02-01 00:00:00',
#    'tavg': 6.2,
#    'tmin': 3.6,
#    'tmax': 9.0,
#    'prcp': 83.0,
#    'wspd': 17.8,
#    'pres': 1010.5,
#    'tsun': 2820},
#   {'date': '2020-03-01 00:00:00',
#    'tavg': 5.9,
#    'tmin': 1.5,
#    'tmax': 10.2,
#    'prcp': 30.0,
#    'wspd': 14.3,
#    'pres': 1018.2,
#    'tsun': 9960},
#   {'date': '2020-04-01 00:00:00',
#    'tavg': 11.2,
#    'tmin': 4.8,
#    'tmax': 17.2,
#    'prcp': 23.0,
#    'wspd': 13.5,
#    'pres': 1018.5,
#    'tsun': 17760},
#   {'date': '2020-05-01 00:00:00',
#    'tavg': 12.9,
#    'tmin': 7.3,
#    'tmax': 18.3,
#    'prcp': 33.0,
#    'wspd': 13.4,
#    'pres': 1019.4,
#    'tsun': 13560},
#   {'date': '2020-06-01 00:00:00',
# ...

# %%
import requests
import pandas as pd

# Example API response (replace this with actual response data)
response_json = {
    "request_id": "758201ff-c34c-452b-bd56-9bafde87d6a5",
    "data": [
        {
            "id": "0x8640bf403c9aaaab:0x2066e03c99f29c05",
            "name": "Blink Charging Station",
            "connectors": [{"type": "Type 2", "count": 2}],
            "formatted_address": "2101 Smith St, Houston, TX 77002",
            "address_components": {
                "district": "Midtown",
                "street_address": "2101 Smith St",
                "city": "Houston",
                "zipcode": "77002",
                "state": "Texas",
                "country": "US"
            },
            "latitude": 29.750237,
            "longitude": -95.3744892,
            "place_link": "https://www.google.com/maps/place/data=!3m1!4b1!4m2!3m1!1s0x8640bf403c9aaaab:0x2066e03c99f29c05",
            "phone_number": "+18006635633",
            "opening_hours": None,
            "rating": None,
            "review_count": 0,
            "website": "http://www.blinkcharging.com",
            "photo": "https://streetviewpixels-pa.googleapis.com/v1/thumbnail?panoid=ri7xrhnMgaLVVhc4O49eAA&cb_client=search.gws-prod.gps&w=86&h=86&yaw=353.2505&pitch=0&thumbfov=100",
            "google_place_id": "ChIJq6qaPEC_QIYRBZzymTzgZiA",
            "google_cid": "2334800007723654149"
        }
    ]
}

# Extract the data
data = response_json['data']

# Prepare a list to hold all the rows for the DataFrame
flattened_data = []

for station in data:
    # Flatten the data
    station_data = {
        'id': station.get('id', None),
        'name': station.get('name', None),
        'formatted_address': station.get('formatted_address', None),
        'district': station.get('address_components', {}).get('district', None),
        'street_address': station.get('address_components', {}).get('street_address', None),
        'city': station.get('address_components', {}).get('city', None),
        'zipcode': station.get('address_components', {}).get('zipcode', None),
        'state': station.get('address_components', {}).get('state', None),
        'country': station.get('address_components', {}).get('country', None),
        'latitude': station.get('latitude', None),
        'longitude': station.get('longitude', None),
        'place_link': station.get('place_link', None),
        'phone_number': station.get('phone_number', None),
        'rating': station.get('rating', None),
        'review_count': station.get('review_count', None),
        'website': station.get('website', None),
        'photo': station.get('photo', None),
        'google_place_id': station.get('google_place_id', None),
        'google_cid': station.get('google_cid', None)
    }
    
    # For 'connectors', we could store them as a count or description
    station_data['connectors_count'] = len(station.get('connectors', []))  # If connectors is a list
    
    # Append the flattened station data
    flattened_data.append(station_data)

# Create a DataFrame
df = pd.DataFrame(flattened_data)

# Show the DataFrame
print(df)
# Out:
#                                       id                    name  \
# 0  0x8640bf403c9aaaab:0x2066e03c99f29c05  Blink Charging Station
#
#                   formatted_address district street_address     city zipcode  \
# 0  2101 Smith St, Houston, TX 77002  Midtown  2101 Smith St  Houston   77002
#
#    state country   latitude  longitude  \
# 0  Texas      US  29.750237 -95.374489
#
#                                           place_link  phone_number rating  \
# 0  https://www.google.com/maps/place/data=!3m1!4b...  +18006635633   None
#
#    review_count                       website  \
# 0             0  http://www.blinkcharging.com
#
#                                                photo  \
# 0  https://streetviewpixels-pa.googleapis.com/v1/...
#
#                google_place_id           google_cid  connectors_count
# 0  ChIJq6qaPEC_QIYRBZzymTzgZiA  2334800007723654149                 1
