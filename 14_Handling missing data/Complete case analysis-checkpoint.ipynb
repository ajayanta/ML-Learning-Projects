# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\KIIT\Downloads\data_science_job.csv")

# %%
df.shape
# Out:
# (19158, 13)

# %%
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
cols=[var for var in df.columns if df[var].isnull().mean()<0.05 and df[var].isnull().mean()>0]
cols
# Out:
# ['city_development_index',
#  'enrolled_university',
#  'education_level',
#  'experience',
#  'training_hours']

# %%
df[cols].head()
# Out:
#    city_development_index enrolled_university education_level  experience  \
# 0                   0.920       no_enrollment        Graduate        20.0
# 1                   0.776       no_enrollment        Graduate        15.0
# 2                   0.624    Full time course        Graduate         5.0
# 3                   0.789                 NaN        Graduate         0.0
# 4                   0.767       no_enrollment         Masters        20.0
#
#    training_hours
# 0            36.0
# 1            47.0
# 2            83.0
# 3            52.0
# 4             8.0

# %%
len(df[cols].dropna())/len(df)
# Out:
# 0.8968577095730244

# %%
new_df=df[cols].dropna()

# %%
sns.histplot(data=df['training_hours'],color='red')
sns.histplot(data=new_df['training_hours'],color='green')
# Out:
# <Axes: xlabel='training_hours', ylabel='Count'>

# %%
sns.kdeplot(df['training_hours'])
sns.kdeplot(new_df['training_hours'])
# Out:
# <Axes: xlabel='training_hours', ylabel='Density'>

# %%
sns.histplot(df['city_development_index'],color='red')
sns.histplot(new_df['city_development_index'],color='green')
# Out:
# <Axes: xlabel='city_development_index', ylabel='Count'>

# %%
sns.kdeplot(df['city_development_index'])
sns.kdeplot(new_df['city_development_index'])
# Out:
# <Axes: xlabel='city_development_index', ylabel='Density'>

# %%
sns.histplot(df['experience'],color='red')
sns.histplot(new_df['experience'],color='green')
# Out:
# <Axes: xlabel='experience', ylabel='Count'>

# %%
sns.kdeplot(df['experience'])
sns.kdeplot(new_df['experience'])
# Out:
# <Axes: xlabel='experience', ylabel='Density'>

# %%
temp=pd.concat([df['enrolled_university'].value_counts()/len(df),df['enrolled_university'].value_counts()/len(df)],axis=1)

# %%
temp.columns=['original','cca']

# %%
temp
# Out:
#                      original       cca
# enrolled_university
# no_enrollment        0.721213  0.721213
# Full time course     0.196106  0.196106
# Part time course     0.062533  0.062533

# %%
temp1=pd.concat([df['education_level'].value_counts()/len(df),df['education_level'].value_counts()/len(df)],axis=1)

# %%
temp1
# Out:
#                     count     count
# education_level
# Graduate         0.605387  0.605387
# Masters          0.227633  0.227633
# High School      0.105282  0.105282
# Phd              0.021610  0.021610
# Primary School   0.016077  0.016077
